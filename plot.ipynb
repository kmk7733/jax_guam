# %%
import matplotlib.pyplot as plt

# %%
difftune = [17.611,
            6.588,
            5.398,
            5.392,
            5.387,
            5.381,
            5.376,
            5.371,
            5.366,
            5.361
            ]
# new param: {'baseline_alloc': {'W_lon': Array([9.9718928e-01, 9.6838284e-01, 1.0288992e+00, 1.0070362e+00,
#        9.4524699e-01, 1.0786196e+00, 9.0771294e-01, 1.0586845e+00,
#        9.9983639e-01, 1.0000000e+03, 1.0000000e+07, 1.0014135e-01],      
# dtype=float32), 'W_lat': Array([9.6073884e-01, 1.0237448e+00, 9.5910001e-01, 1.0188550e+00,
#        9.9895185e-01, 9.7461605e-01, 1.0462468e+00, 1.0173635e+00,
#        1.0000000e+03, 1.0000000e+03, 1.0000004e+00], dtype=float32)},
#  'lqr': {'Q_lon': Array([   1.0905987,   71.40165  , 1000.0003   ], dtype=float32), 
# 'R_lon': Array([1.7044388 , 0.20694287, 0.6607428 ], dtype=float32),
#  'Q_lat': Array([9.474091e-01, 1.000000e+03, 1.000000e+03], dtype=float32), 
# 'R_lat': Array([0.91865   , 0.98199683, 0.9993944 ], dtype=float32)}}
autotune_lqr = [17.611,
                14.172,
                12.016,
                10.498,
                9.348,
                8.433,
                7.671,
                7.008,
                7.008,
                7.008,
            ]
#{'lqr': {'Q_lon': Array([1.9725220e-02, 4.5653448e-02, 9.9628168e+02], dtype=float32), 
# 'R_lon': Array([2.1794438 , 0.12229261, 1.4035431 ], dtype=float32), 
# 'Q_lat': Array([2.2229776e-02, 9.9960907e+02, 9.8621320e+02], dtype=float32), 
# 'R_lat': Array([1.6464634 , 0.95689696, 2.0273466 ], dtype=float32)}}
autotune_alloc = [17.611,
            17.617,
            17.624,
            17.632,
            17.642,
            17.652,
            17.663,
            17.675,
            17.688,
            17.703
            ]
# {'baseline_alloc': {'W_lon': Array([1.1037526e+00, 1.0798738e+00, 9.8751879e-01, 1.0078821e+00,
#        1.0026834e+00, 1.0265741e+00, 9.3199646e-01, 1.1225352e+00,
#        9.6473014e-01, 9.8715515e+02, 1.0000000e+07, 1.0020795e-01],      dtype=float32), 'W_lat': Array([1.10658741e+00, 9.76910949e-01, 1.13371110e+00, 1.00298977e+00,
#        1.23521781e+00, 9.99419451e-01, 8.79117608e-01, 1.20385265e+00,
#        1.00133301e+03, 1.00036255e+03, 9.29004312e-01], dtype=float32)}}

autotune=[17.611,
          17.611,
          17.611,
          17.611,
          17.611,
          17.611,
          17.611,
          17.611,
          17.611,
          17.611,
          ]

# %%
plt.plot(difftune, label='DiffTune')
plt.plot(autotune, label='AutoTune' )
plt.plot(autotune_lqr, label='AutoTune (LQR only)' )
plt.plot(autotune_alloc, label='AutoTune (W only)' )
plt.legend()
plt.ylabel('MSE')
plt.xlabel('Itr')
plt.show()

# %%
difftune = [15.055,
            0.823,
            0.816,
            0.811,
            0.806,
            0.803,
            0.800,
            0.797,
            0.795,
            0.793
            ]
# new param: {'baseline_alloc': {'W_lon': Array([9.9835312e-01, 1.0067989e+00, 9.9328172e-01, 
#                                                1.0013999e+00,
#        9.9840462e-01, 9.9760437e-01, 1.0024661e+00, 1.0016309e+00,
#        9.9998206e-01, 1.0000000e+03, 1.0000000e+07, 1.0000000e-01],      
#        dtype=float32), 'W_lat': Array([9.9462128e-01, 1.0027858e+00, 9.9576169e-01,
#                                         1.0029647e+00,
#        9.9979568e-01, 9.9604332e-01, 1.0059477e+00, 1.0020484e+00,
#        1.0000000e+03, 1.0000000e+03, 1.0000000e+00], dtype=float32)}, 
#        'lqr': {'Q_lon': Array([1.9872651e-01, 7.6820354e+00, 1.0000000e+03], dtype=float32), 
#                'R_lon': Array([0.9901444, 0.9102108, 0.9909004], dtype=float32), 
#                'Q_lat': Array([1.0308021e-01, 1.0000000e+03, 1.0000000e+03], dtype=float32), 
#                'R_lat': Array([0.9997158, 0.9999825, 0.9999983], dtype=float32)}}
autotune_lqr = [15.055,
                11.393,
                9.089,
                7.423,
                6.108,
                4.996,
                3.994,
                3.027,
                3.027,
                3.027,
            ]
# {'lqr': {'Q_lon': Array([1.9725220e-02, 4.5653448e-02, 9.9628168e+02], dtype=float32), 
#          'R_lon': Array([2.1794438 , 0.12229261, 1.4035431 ], dtype=float32),
#          'Q_lat': Array([2.2229776e-02, 9.9960907e+02, 9.8621320e+02], dtype=float32),
#            'R_lat': Array([1.6464634 , 0.95689696, 2.0273466 ], dtype=float32)}}
autotune_alloc = [15.055,
                  15.064,
                  15.074,
                  15.085,
                  15.098,
                  15.111,
                  15.125,
                  15.142,
                  15.158,
                  15.177
            ]
# {'baseline_alloc': {'W_lon': Array([1.1037526e+00, 1.0798738e+00, 9.8751879e-01, 1.0078821e+00,
#        1.0026834e+00, 1.0265741e+00, 9.3199646e-01, 1.1225352e+00,
#        9.6473014e-01, 9.8715515e+02, 1.0000000e+07, 1.0020795e-01],      
# dtype=float32), 'W_lat': Array([1.10658741e+00, 9.76910949e-01, 1.13371110e+00, 1.00298977e+00,
#        1.23521781e+00, 9.99419451e-01, 8.79117608e-01, 1.20385265e+00,
#        1.00133301e+03, 1.00036255e+03, 9.29004312e-01], dtype=float32)}}

autotune=[15.055,
          15.055,
          15.055,
          15.055,
          15.055,
          15.055,
          17.550,
          17.550,
          17.550,
          17.550,
          ]

# %%
plt.plot(difftune, label='DiffTune')
plt.plot(autotune, label='AutoTune' )
plt.plot(autotune_lqr, label='AutoTune (LQR only)' )
plt.plot(autotune_alloc, label='AutoTune (W only)' )
plt.legend()
plt.ylabel('MSE')
plt.xlabel('Itr')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
T_t = np.arange(0, 21, 1)
T_pos_bii = np.vstack((T_t, 10*np.cos(2*np.pi/300*T_t), 10*np.sin(2*np.pi/300*T_t))).T
print(T_pos_bii.shape)
ax = plt.figure().add_subplot(projection='3d')
ax.set_facecolor('white')
ax.plot(T_pos_bii[:,0],T_pos_bii[:,1],T_pos_bii[:,2])
ax.set_xlabel('North')
ax.set_ylabel('East')
ax.set_zlabel('Height')
plt.autoscale(enable=True, axis='x', tight=True)
plt.show()
# Out:
# (21, 3)

# %%
T_pos_bii = np.vstack((T_t, 10*np.cos(2*np.pi/300*T_t), 10*np.sin(2*np.pi/300*T_t))).T

plt.plot(T_pos_bii[:,0], label='North')
plt.plot(T_pos_bii[:,1], label='East')
plt.plot(T_pos_bii[:,2], label='Height')
plt.legend()
plt.xlabel('[m]')
plt.ylabel('[m]')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
